# %%
import matplotlib.pyplot as plt
import pandas as pd
import requests
from Bio.KEGG import Enzyme
import matplotlib
import io
import time
import pickle
import re
from rich.progress import Progress
from rdkit import Chem
from collections import Counter
import numpy as np
from rdkit import Chem
from rdkit.Chem import rdFMCS
import pubchempy as pcp
from bs4 import BeautifulSoup
from urllib.parse import quote
import json

import math
import os

# %%
inchi_ligands = pd.read_pickle("parity_calcs/all_chem_descriptors_inchi_unique_pairs.pkl")

#inchi_ligands.index = inchi_ligands.ligand_entity_id
#inchi_ligands.head(1000).to_csv("pdb_ligands_inchi_1k.csv")

# %%
inchi_ligands.loc[inchi_ligands.pdb_entry_id == "6hp0"]
# Out:
#         pdb_entry_id ligand_entity_id  \
# 1287917         6hp0           6hp0_9
# 1287923         6hp0           6hp0_8
# 1287933         6hp0           6hp0_7
# 1287940         6hp0           6hp0_6
# 1287942         6hp0           6hp0_5
# 1287948         6hp0           6hp0_4
# 1287973         6hp0           6hp0_3
# 1287987         6hp0           6hp0_2
#
#                                                 descriptor descriptor_type  \
# 1287917  InChI=1S/C6H14O4/c7-1-3-9-5-6-10-4-2-8/h7-8H,1...           InChI
# 1287923               InChI=1S/C2H6O2/c3-1-2-4/h3-4H,1-2H2           InChI
# 1287933  InChI=1S/C8H15NO6/c1-3(11)9-5-7(13)6(12)4(2-10...           InChI
# 1287940  InChI=1S/C17H26N4O5/c1-4-13(5-2)26-15-7-11(17(...           InChI
# 1287942                                    InChI=1S/Ca/q+2           InChI
# 1287948  InChI=1S/C6H12O5/c1-2-3(7)4(8)5(9)6(10)11-2/h2...           InChI
# 1287973  InChI=1S/C6H12O5/c1-2-3(7)4(8)5(9)6(10)11-2/h2...           InChI
# 1287987  InChI=1S/C6H12O5/c1-2-3(7)4(8)5(9)6(10)11-2/h2...           InChI
#
#         protein_polymer_EC
# 1287917           3.2.1.18
# 1287923           3.2.1.18
# 1287933           3.2.1.18
# 1287940           3.2.1.18
# 1287942           3.2.1.18
# 1287948           3.2.1.18
# 1287973           3.2.1.18
# 1287987           3.2.1.18

# %%
inchi_ligands.descriptor.nunique()
# Out:
# 25542

# %%
print(f"""
Chains domains contains all of the chains and their associated cath/scop/pfam domains in which EC number for the entity was not null: {chains_domains.pdb.nunique()}
These map to {chains_domains.EC_descriptor.nunique()} EC numbers in PDBe-graph. This may contain partial EC numbers. 
When these are expanded to include all sub EC numbers, the total number of EC numbers searched is {chains_domains.filled_EC_descriptor.nunique()}
""")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 print(f"""
# ----> 2 Chains domains contains all of the chains and their associated cath/scop/pfam domains in which EC number for the entity was not null: {chains_domains.pdb.nunique()}
#       3 These map to {chains_domains.EC_descriptor.nunique()} EC numbers in PDBe-graph. This may contain partial EC numbers.
#       4 When these are expanded to include all sub EC numbers, the total number of EC numbers searched is {chains_domains.filled_EC_descriptor.nunique()}
#       5 """)
#
# NameError: name 'chains_domains' is not defined

# %%
chains_domains_chem_descriptors = pd.read_pickle("parity_calcs/all_chem_descriptors_inchi_unique_pairs.pkl")

print(f"""
We have a total of {chains_domains_chem_descriptors.ligand_entity_id.nunique()} ligands in this file.
and {chains_domains_chem_descriptors.protein_polymer_EC.str.split(",").explode().nunique()} EC numbers are associated with these.
""")
# Out:
# We have a total of 213957 ligands in this file.
# and 3521 EC numbers are associated with these.

# %%
chains_domains_chem_descriptors.loc[chains_domains_chem_descriptors.pdb_entry_id == "6hzx"]
# Out:
#        pdb_entry_id ligand_entity_id  \
# 489393         6hzx           6hzx_9
# 489403         6hzx           6hzx_8
# 489404         6hzx           6hzx_7
# 489415         6hzx           6hzx_6
# 489419         6hzx           6hzx_5
# 489427         6hzx           6hzx_4
# 489433         6hzx           6hzx_3
# 489435         6hzx           6hzx_2
#
#                                                descriptor descriptor_type  \
# 489393           InChI=1S/C3H8O3/c4-1-3(6)2-5/h3-6H,1-2H2           InChI
# 489403  InChI=1S/C12H10N2O3/c13-10-3-1-2-9-7(5-11(16)1...           InChI
# 489404  InChI=1S/C10H8N2O3/c11-6-3-1-2-5-8(13)4-7(10(1...           InChI
# 489415  InChI=1S/C12H10N2O5/c13-7-3-1-2-6-9(19-5-10(15...           InChI
# 489419  InChI=1S/C7H8N2O2/c8-4-5-2-1-3-6(9-5)7(10)11/h...           InChI
# 489427  InChI=1S/C13H15N3O3/c14-5-2-6-19-11-7-10(13(17...           InChI
# 489433  InChI=1S/C19H23N3O5S/c20-28(25,26)18-8-6-16(7-...           InChI
# 489435                                    InChI=1S/Zn/q+2           InChI
#
#        protein_polymer_EC
# 489393            4.2.1.1
# 489403            4.2.1.1
# 489404            4.2.1.1
# 489415            4.2.1.1
# 489419            4.2.1.1
# 489427            4.2.1.1
# 489433            4.2.1.1
# 489435            4.2.1.1

# %%
parity_calcs = pd.read_pickle("parity_calcs/parity_calcs/all_parity_calcs.pkl")
parity_calcs["pdb"] = parity_calcs['pdb_ligand'].str[:4]
chains_domains_parity_calcs = parity_calcs.loc[parity_calcs.pdb_ligand.isin(chains_domains_chem_descriptors.ligand_entity_id.unique())]

# %%
parity_calcs.loc[parity_calcs.pdb == "6hzx"].pdb.unique()
# Out:
# array(['6hzx'], dtype=object)

# %%
unique_chains_domains_pdbs = pd.DataFrame({"pdb_id" : chains_domains_parity_calcs.pdb.unique()})

#unique_chains_domains_pdbs.to_csv("unique_chains_domains_pdbs.csv", index = False, header = None)

pdbline = unique_chains_domains_pdbs["pdb_id"].str.upper().tolist()
pdbline = ",".join(pdbline)

with open("unique_chains_domains_pdbs.txt", "w") as file:
    file.write(pdbline)

# %%
chains_domains_parity_calcs.loc[(chains_domains_parity_calcs.error.isna()) & (chains_domains_parity_calcs.error.str.startswith("Parity error: index 0 is out of bounds for axi") == False) & (chains_domains_parity_calcs.error != "No KEGG Compounds found for EC") & (chains_domains_parity_calcs.pdb == "6hzx")]
# Out:
# Empty DataFrame
# Columns: [pdb_ligand, compound, score, error, cancelled, pdb]
# Index: []

# %%
chains_domains_parity_calcs.loc[chains_domains_parity_calcs.pdb == "6hzx"]
# Out:
#       pdb_ligand     compound     score error cancelled   pdb
# 19020     6hzx_9  KEGG_C01353  0.250000  None     False  6hzx
# 19021     6hzx_9  KEGG_C00011  0.285714  None     False  6hzx
# 19022     6hzx_9  KEGG_C00001  0.166667  None     False  6hzx
# 19023     6hzx_9  KEGG_C01353  0.250000  None     False  6hzx
# 19024     6hzx_9  KEGG_C00011  0.285714  None     False  6hzx
# 19025     6hzx_9  KEGG_C00001  0.166667  None     False  6hzx
# 19026     6hzx_8  KEGG_C01353  0.050000  None     False  6hzx
# 19027     6hzx_8  KEGG_C00011  0.052632  None     False  6hzx
# 19028     6hzx_8  KEGG_C00001  0.058824  None     False  6hzx
# 19029     6hzx_8  KEGG_C01353  0.050000  None     False  6hzx
# 19030     6hzx_8  KEGG_C00011  0.052632  None     False  6hzx
# 19031     6hzx_8  KEGG_C00001  0.058824  None     False  6hzx
# 19032     6hzx_7  KEGG_C01353  0.055556  None     False  6hzx
# 19033     6hzx_7  KEGG_C00011  0.058824  None     False  6hzx
# 19034     6hzx_7  KEGG_C00001  0.066667  None     False  6hzx
# 19035     6hzx_7  KEGG_C01353  0.055556  None     False  6hzx
# 19036     6hzx_7  KEGG_C00011  0.058824  None     False  6hzx
# 19037     6hzx_7  KEGG_C00001  0.066667  None     False  6hzx
# 19038     6hzx_6  KEGG_C01353  0.045455  None     False  6hzx
# 19039     6hzx_6  KEGG_C00011  0.047619  None     False  6hzx
# 19040     6hzx_6  KEGG_C00001  0.052632  None     False  6hzx
# 19041     6hzx_6  KEGG_C01353  0.045455  None     False  6hzx
# 19042     6hzx_6  KEGG_C00011  0.047619  None     False  6hzx
# 19043     6hzx_6  KEGG_C00001  0.052632  None     False  6hzx
# 19044     6hzx_5  KEGG_C01353  0.071429  None     False  6hzx
# 19045     6hzx_5  KEGG_C00011  0.076923  None     False  6hzx
# 19046     6hzx_5  KEGG_C00001  0.090909  None     False  6hzx
# 19047     6hzx_5  KEGG_C01353  0.071429  None     False  6hzx
# 19048     6hzx_5  KEGG_C00011  0.076923  None     False  6hzx
# 19049     6hzx_5  KEGG_C00001  0.090909  None     False  6hzx
# 19050     6hzx_4  KEGG_C01353  0.045455  None     False  6hzx
# 19051     6hzx_4  KEGG_C00011  0.047619  None     False  6hzx
# 19052     6hzx_4  KEGG_C00001  0.052632  None     False  6hzx
# 19053     6hzx_4  KEGG_C01353  0.045455  None     False  6hzx
# 19054     6hzx_4  KEGG_C00011  0.047619  None     False  6hzx
# 19055     6hzx_4  KEGG_C00001  0.052632  None     False  6hzx
# 19056     6hzx_3  KEGG_C01353  0.032258  None     False  6hzx
# 19057     6hzx_3  KEGG_C00011  0.033333  None     False  6hzx
# 19058     6hzx_3  KEGG_C00001  0.035714  None     False  6hzx
# 19059     6hzx_3  KEGG_C01353  0.032258  None     False  6hzx
# 19060     6hzx_3  KEGG_C00011  0.033333  None     False  6hzx
# 19061     6hzx_3  KEGG_C00001  0.035714  None     False  6hzx
# 19062     6hzx_2  KEGG_C01353  0.000000  None     False  6hzx
# 19063     6hzx_2  KEGG_C00011  0.000000  None     False  6hzx
# 19064     6hzx_2  KEGG_C00001  0.000000  None     False  6hzx
# 19065     6hzx_2  KEGG_C01353  0.000000  None     False  6hzx
# 19066     6hzx_2  KEGG_C00011  0.000000  None     False  6hzx
# 19067     6hzx_2  KEGG_C00001  0.000000  None     False  6hzx

# %%
ligands_with_score = chains_domains_parity_calcs.loc[(chains_domains_parity_calcs.compound.isna() == False)]
ligands_missing_score = chains_domains_parity_calcs.loc[(chains_domains_parity_calcs.compound.isna()) & (chains_domains_parity_calcs.pdb_ligand.isin(ligands_with_score.pdb_ligand.unique()) == False)]

# %%
chains_domains_parity_calcs.loc[chains_domains_parity_calcs.error == "No KEGG Compounds found for EC"]
# Out:
#       pdb_ligand compound  score                           error cancelled  \
# 658       6yza_5     None    0.0  No KEGG Compounds found for EC      None
# 659       6yza_4     None    0.0  No KEGG Compounds found for EC      None
# 660       6yza_3     None    0.0  No KEGG Compounds found for EC      None
# 661       6yza_2     None    0.0  No KEGG Compounds found for EC      None
# 861       3nps_6     None    0.0  No KEGG Compounds found for EC      None
# ...          ...      ...    ...                             ...       ...
# 52668     4hn2_2     None    0.0  No KEGG Compounds found for EC      None
# 52753     4rsl_3     None    0.0  No KEGG Compounds found for EC      None
# 52754     4rsl_2     None    0.0  No KEGG Compounds found for EC      None
# 52817     5he5_3     None    0.0  No KEGG Compounds found for EC      None
# 52818     5he5_2     None    0.0  No KEGG Compounds found for EC      None
#
#         pdb
# 658    6yza
# 659    6yza
# 660    6yza
# 661    6yza
# 861    3nps
# ...     ...
# 52668  4hn2
# 52753  4rsl
# 52754  4rsl
# 52817  5he5
# 52818  5he5
#
# [58985 rows x 6 columns]

# %%
ligands_with_score
# Out:
#       pdb_ligand     compound     score error cancelled   pdb
# 0         1b42_3  KEGG_C00002  0.135135  None     False  1b42
# 1         1b42_3  KEGG_C00046  0.062500  None     False  1b42
# 2         1b42_3  KEGG_C00013  0.000000  None     False  1b42
# 3         1b42_3  KEGG_C00046  0.062500  None     False  1b42
# 4         1b42_3  KEGG_C00002  0.135135  None     False  1b42
# ...          ...          ...       ...   ...       ...   ...
# 52812     5h1y_3  KEGG_C00009  0.000000  None     False  5h1y
# 52813     5h1y_2  KEGG_C00002  0.125000  None     False  5h1y
# 52814     5h1y_2  KEGG_C00001  0.200000  None     False  5h1y
# 52815     5h1y_2  KEGG_C00008  0.142857  None     False  5h1y
# 52816     5h1y_2  KEGG_C00009  0.666667  None     False  5h1y
#
# [23390841 rows x 6 columns]

# %%
ligands_with_score.reset_index().pdb_ligand.value_counts()
# Out:
# pdb_ligand
# 4u0p_4    51648
# 4u0o_2    51648
# 5exk_9    51648
# 5exk_8    51648
# 4u0p_3    51648
#           ...
# 1tb6_4        1
# 1tb6_5        1
# 1tb6_6        1
# 1tb6_7        1
# 8a3q_4        1
# Name: count, Length: 171414, dtype: int64

# %%
ligands_with_score.pdb_ligand.nunique() + ligands_missing_score.pdb_ligand.nunique()
ligands_max_score = ligands_with_score.reset_index(drop = True).iloc[ligands_with_score.reset_index(drop = True).groupby("pdb_ligand")["score"].idxmax()]

# %%
# Out:
# 213957

# %%
# Out:
# 42543

# %%
max_scores = ligands_with_score.loc[ligands_with_score.compound.isin(ner_compounds) == False].groupby('pdb_ligand')['score'].max()

plt.hist(max_scores, edgecolor='black')  # Adjust the number of bins as needed
plt.xlabel('Score')
plt.ylabel('Frequency')
plt.title('Histogram of Parity Scores for PDB-ligand Cognate Ligand')
plt.show()

# %%
final_kegg_compound_reaction_enzyme_df = pd.read_pickle("kegg_information/final_kegg_compound_reaction_enzyme_df.pkl")

# %%
ner_compounds = final_kegg_compound_reaction_enzyme_df.loc[final_kegg_compound_reaction_enzyme_df.search_type == "NER"].unique_id.values.tolist()
entities_compounds = final_kegg_compound_reaction_enzyme_df.loc[final_kegg_compound_reaction_enzyme_df.search_type == "entities"].unique_id.values.tolist()

# %%
ligands_with_score.groupby('pdb_ligand')['score'].max() 
#ligands_with_score.loc[(ligands_with_score.compound.isin(entities_compounds))].score.mean()
# Out:
# pdb_ligand
# 107l_2    0.000000
# 107l_3    0.187500
# 108l_2    0.000000
# 108l_3    0.187500
# 109l_2    0.000000
#             ...
# 9rub_4    1.000000
# 9xia_2    0.692308
# 9xia_3    0.000000
# 9xim_2    1.000000
# 9xim_3    0.000000
# Name: score, Length: 171414, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.kdeplot(ligands_with_score["score"], fill=True)
plt.xlabel('X-axis label')
plt.ylabel('Density')
plt.title('KDE Plot of Experimental Data')
plt.show()

# %%
print(f"""
{round((len(max_scores.loc[max_scores > 0.55])/ len(max_scores)) * 100, 2)} % of pdb ligands have a cognate ligand match >0.55 PARITY score
""")
# Out:
# 19.6 % of pdb ligands have a cognate ligand match >0.55 PARITY score

# %%
ligands_missing_score.iloc[0]["error"]
# Out:
# 'No KEGG Compounds found for EC'

# %%
chains_domains.loc[(chains_domains.pdb.isin(ligands_missing_score.pdb.unique()))].filled_EC_descriptor.nunique()
# Out:
# 7553

# %%
chains_domains.loc[(chains_domains.pdb.isin(ligands_with_score.pdb.unique()))].filled_EC_descriptor.nunique()
# Out:
# 6816

# %%
chains_domains_parity_calcs.loc[(chains_domains_parity_calcs.kegg_ligand.isna() == False) & (chains_domains_parity_calcs.kegg_ligand.str.startswith("G")) & (chains_domains_parity_calcs.score > 0.4)]

# %%
compound_list = get_enzyme_ligands("3.4.23.46", kegg_reaction_df, kegg_enzyme_df)
scores_list = parity_score_inchi("5he5_2", "InChI=1S/C4H6O6/c5-1(3(7)8)2(6)4(9)10/h1-2,5-6H,(H,7,8)(H,9,10)/t1-,2-/m1/s1", compound_list, kegg_compounds_df, timeout = 30)

# %% [markdown]
# We performed parity calcs between pairs of pdb ligands and potential cognate ligands (in the parity calcs file).

# %%
print(f"""A total of {parity_calcs.pdb_ligand.nunique()} pdb ligands were tested, against a total of {parity_calcs.kegg_ligand.nunique()} kegg ligands""")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1091849/152871355.py in ?()
# ----> 1 print(f"""A total of {parity_calcs.pdb_ligand.nunique()} pdb ligands were tested, against a total of {parity_calcs.kegg_ligand.nunique()} kegg ligands""")
#
# ~/miniconda3/envs/cognate_ligand_project/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'kegg_ligand'

# %%
# Out:
# domain_owner
# uniquely_binding_domain    147917
# partner_binding_domain      56317
# minor_binding_domain        40271
# dominant_binding_domain     33380
# Name: count, dtype: int64

# %%
# Out:
#         pdb_id cath_domain ligand_entity_id bound_ligand_id bound_ligand_name  \
# 1537147   10gs     10gsA02           10gs_2      10gs_2_C_1               VWW
# 1537155   10gs     10gsA01           10gs_2      10gs_2_C_1               VWW
# 1537143   10gs     10gsB02           10gs_2      10gs_2_E_1               VWW
# 1537151   10gs     10gsB01           10gs_2      10gs_2_E_1               VWW
# 3599153   11ba     11baA00           11ba_3      11ba_3_D_1               UPA
# ...        ...         ...              ...             ...               ...
# 3730290   9nse     9nseB01           9nse_8      9nse_8_R_1               GOL
# 3730024   9nse     9nseB03           9nse_8      9nse_8_R_1               GOL
# 2169372   9rub     9rubB01           9rub_2      9rub_2_C_1               RUB
# 2169371   9rub     9rubA02           9rub_2      9rub_2_C_1               RUB
# 3743542   9xim     9ximD00           9xim_2      9xim_2_N_1               XLS
#
#          domain_counts             domain_owner
# 1537147              4     minor_binding_domain
# 1537155             76  dominant_binding_domain
# 1537143              4     minor_binding_domain
# 1537151             77  dominant_binding_domain
# 3599153             68  dominant_binding_domain
# ...                ...                      ...
# 3730290              3   partner_binding_domain
# 3730024              4   partner_binding_domain
# 2169372              4     minor_binding_domain
# 2169371             17  dominant_binding_domain
# 3743542             28  dominant_binding_domain
#
# [129968 rows x 7 columns]

# %% [markdown]
# Do certain domains only exist as "partner domains"?

# %% [markdown]
# So what about if we use surfaces to calculate the interactions between ligands in the PDB? This can give use an understanding of favourable and unfavourable interactions.

# %%
kegg_compounds = pd.read_pickle("kegg_information/final_kegg_compound_reaction_enzyme_df.pkl")

# %%
kegg_compounds.loc[kegg_compounds.search_type != "NER"].compound_id.nunique()
# Out:
# 6142

# %%
sifts_pdb_ec = pd.read_csv("sifts_pdb_chain_enzyme.tsv", sep = "\t", comment = "#")
sifts_pdb_ec.groupby(['PDB', 'EC_NUMBER']).size()

len(sifts_pdb_ec.groupby(['PDB', 'EC_NUMBER']).size().reset_index())
sifts_pdb_ec.PDB.nunique()
inchi_ligands.pdb_entry_id.nunique()
ec_nums_exploded = ec_nums["(e.EC)"].str.split(",").explode().drop_duplicates()
len(ec_nums_exploded)
ec_nums_exploded.loc[ec_nums_exploded.isin(sifts_pdb_ec.EC_NUMBER.unique()) == False]

#what are uniprot groups and how can we use these to our advantage?
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[245], line 1
# ----> 1 sifts_pdb_ec = pd.read_csv("sifts_pdb_chain_enzyme.tsv", sep = "\t", comment = "#")
#       2 sifts_pdb_ec.groupby(['PDB', 'EC_NUMBER']).size()
#       4 len(sifts_pdb_ec.groupby(['PDB', 'EC_NUMBER']).size().reset_index())
#
# File ~/miniconda3/envs/cognate_ligand_project/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/cognate_ligand_project/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/miniconda3/envs/cognate_ligand_project/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/cognate_ligand_project/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/miniconda3/envs/cognate_ligand_project/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'sifts_pdb_chain_enzyme.tsv'
